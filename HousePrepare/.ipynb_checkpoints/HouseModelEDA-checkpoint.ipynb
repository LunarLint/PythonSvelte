# %% [markdown]
# ## 임포트 / 데이터 체크

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
# %matplotlib inline

# %%
# csv 파일 불러오기
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")
print(df_train.shape, df_test.shape)
# Out:
# (1460, 81) (1459, 80)

# %%
# 정답파일 샘플 확인
df_train.sample(15)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1154  1155          60       RL          NaN    13700   Pave   NaN      IR1
# 320    321          60       RL        111.0    16259   Pave   NaN      Reg
# 941    942          60       RL          NaN     8755   Pave   NaN      IR1
# 260    261          80       RL        120.0    19296   Pave   NaN      Reg
# 647    648          20       RL         85.0    10452   Pave   NaN      IR1
# 307    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 555    556          45       RM         58.0     6380   Pave   NaN      Reg
# 597    598         120       RL         53.0     3922   Pave   NaN      Reg
# 1134  1135          60       RL         57.0     8773   Pave   NaN      IR1
# 938    939          60       RL         73.0     8760   Pave   NaN      Reg
# ...

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# 정답 파일 정보 확인
# 숫자형 : 37 개
# 객체형 : 43 개
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# 변수형 나누기
num_feats = df_train.dtypes[df_train.dtypes != "object"].index
print("숫자형 변수: ", len(num_feats))

catg_feats = df_train.dtypes[df_train.dtypes == "object"].index
print("객체형 변수: ", len(catg_feats))
# Out:
# 숫자형 변수:  38
# 객체형 변수:  43

# %%
#숫자형 변수명 확인
print(df_train[num_feats].columns)
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
#범주형 변수명 확인
print(df_train[catg_feats].columns)
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# ### 이상치 제거

# %%
# 이상치 제거(IQR 방법)
def detect_outliers(df, n, features):
    outlier_indices = []
    for col in features:
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1

        outlier_step = 1.5 * IQR

        outlier_list_col = df[(df[col] < Q1 - outlier_step)
                              | (df[col] > Q3 + outlier_step)].index
        
        outlier_indices.extend(outlier_list_col)
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(k for k, v in outlier_indices.items() if v > n)

    return multiple_outliers


Outliers_to_drop = detect_outliers(df_train, 2, ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
                                                 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
                                                 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
                                                 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
                                                 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
                                                 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
                                                 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
                                                 'MiscVal', 'MoSold', 'YrSold'])

# 이상치가 발견된 행 확인
df_train.loc[Outliers_to_drop]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 93      94         190  C (all)         60.0     7200   Pave   NaN      Reg
# 125    126         190       RM         60.0     6780   Pave   NaN      Reg
# 165    166         190       RL         62.0    10106   Pave   NaN      Reg
# 172    173         160       RL         44.0     5306   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1350  1351          90       RL         91.0    11643   Pave   NaN      Reg
# 634    635          90       RL         64.0     6979   Pave   NaN      Reg
# 910    911          90       RL         80.0    11600   Pave   NaN      Reg
# 1292  1293          70       RM         60.0     6600   Pave   NaN      Reg
# 912    913          30       RM         51.0     6120   Pave   NaN      Reg
#
# ...

# %%
# 이상치 제거 및 결과 확인
df_train = df_train.drop(Outliers_to_drop).reset_index(drop=True)
df_train.shape
# Out:
# (1338, 81)

# %% [markdown]
# ### 결측치 확인

# %%
# df_train 결측치 확인
for col in df_train.columns:
    mvalue = '열: {:>15}\t 빈값: {:.0f} 개'.format(
        col,  df_train[col].isnull().sum())
    print(mvalue)
# Out:
# 열:              Id	 빈값: 0 개
# 열:      MSSubClass	 빈값: 0 개
# 열:        MSZoning	 빈값: 0 개
# 열:     LotFrontage	 빈값: 229 개
# 열:         LotArea	 빈값: 0 개
# 열:          Street	 빈값: 0 개
# 열:           Alley	 빈값: 1259 개
# 열:        LotShape	 빈값: 0 개
# 열:     LandContour	 빈값: 0 개
# 열:       Utilities	 빈값: 0 개
# 열:       LotConfig	 빈값: 0 개
# 열:       LandSlope	 빈값: 0 개
# 열:    Neighborhood	 빈값: 0 개
# 열:      Condition1	 빈값: 0 개
# 열:      Condition2	 빈값: 0 개
# 열:        BldgType	 빈값: 0 개
# 열:      HouseStyle	 빈값: 0 개
# 열:     OverallQual	 빈값: 0 개
# 열:     OverallCond	 빈값: 0 개
# 열:       YearBuilt	 빈값: 0 개
# 열:    YearRemodAdd	 빈값: 0 개
# 열:       RoofStyle	 빈값: 0 개
# 열:        RoofMatl	 빈값: 0 개
# 열:     Exterior1st	 빈값: 0 개
# 열:     Exterior2nd	 빈값: 0 개
# 열:      MasVnrType	 빈값: 7 개
# 열:      MasVnrArea	 빈값: 7 개
# 열:       ExterQual	 빈값: 0 개
# 열:       ExterCond	 빈값: 0 개
# 열:      Foundation	 빈값: 0 개
# 열:        BsmtQual	 빈값: 31 개
# 열:        BsmtCond	 빈값: 31 개
# 열:    BsmtExposure	 빈값: 32 개
# ...

# %%
# df_test 결측치 확인
for col in df_test.columns:
    mvalue = '열: {:>15}\t 빈값: {:.0f} 개'.format(
        col,  df_test[col].isnull().sum())
    print(mvalue)
# Out:
# 열:              Id	 빈값: 0 개
# 열:      MSSubClass	 빈값: 0 개
# 열:        MSZoning	 빈값: 4 개
# 열:     LotFrontage	 빈값: 227 개
# 열:         LotArea	 빈값: 0 개
# 열:          Street	 빈값: 0 개
# 열:           Alley	 빈값: 1352 개
# 열:        LotShape	 빈값: 0 개
# 열:     LandContour	 빈값: 0 개
# 열:       Utilities	 빈값: 2 개
# 열:       LotConfig	 빈값: 0 개
# 열:       LandSlope	 빈값: 0 개
# 열:    Neighborhood	 빈값: 0 개
# 열:      Condition1	 빈값: 0 개
# 열:      Condition2	 빈값: 0 개
# 열:        BldgType	 빈값: 0 개
# 열:      HouseStyle	 빈값: 0 개
# 열:     OverallQual	 빈값: 0 개
# 열:     OverallCond	 빈값: 0 개
# 열:       YearBuilt	 빈값: 0 개
# 열:    YearRemodAdd	 빈값: 0 개
# 열:       RoofStyle	 빈값: 0 개
# 열:        RoofMatl	 빈값: 0 개
# 열:     Exterior1st	 빈값: 1 개
# 열:     Exterior2nd	 빈값: 1 개
# 열:      MasVnrType	 빈값: 16 개
# 열:      MasVnrArea	 빈값: 15 개
# 열:       ExterQual	 빈값: 0 개
# 열:       ExterCond	 빈값: 0 개
# 열:      Foundation	 빈값: 0 개
# 열:        BsmtQual	 빈값: 44 개
# 열:        BsmtCond	 빈값: 45 개
# 열:    BsmtExposure	 빈값: 44 개
# ...

# %%
# 결측치 바 그래프로 확인
missing = df_train.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar(figsize=(6, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 비대칭도(Skewness) 확인

# %%
# 숫자형 비대칭도, 첨도 확인
for col in num_feats:
    print('{:15}'.format(col),
          '비대칭도(Skewness): {:05.2f}'.format(df_train[col].skew()),
          '   ',
          '첨도(Kurtosis): {:06.2f}'.format(df_train[col].kurt())
          )
# Out:
# Id              비대칭도(Skewness): 00.00     첨도(Kurtosis): -01.19
# MSSubClass      비대칭도(Skewness): 01.37     첨도(Kurtosis): 001.49
# LotFrontage     비대칭도(Skewness): 01.59     첨도(Kurtosis): 013.04
# LotArea         비대칭도(Skewness): 07.78     첨도(Kurtosis): 123.55
# OverallQual     비대칭도(Skewness): 00.16     첨도(Kurtosis): -00.05
# OverallCond     비대칭도(Skewness): 00.74     첨도(Kurtosis): 001.23
# YearBuilt       비대칭도(Skewness): -0.58     첨도(Kurtosis): -00.60
# YearRemodAdd    비대칭도(Skewness): -0.52     첨도(Kurtosis): -01.27
# MasVnrArea      비대칭도(Skewness): 02.69     첨도(Kurtosis): 011.04
# BsmtFinSF1      비대칭도(Skewness): 00.65     첨도(Kurtosis): -00.50
# BsmtFinSF2      비대칭도(Skewness): 04.86     첨도(Kurtosis): 026.86
# BsmtUnfSF       비대칭도(Skewness): 00.87     첨도(Kurtosis): 000.29
# TotalBsmtSF     비대칭도(Skewness): 00.29     첨도(Kurtosis): 001.17
# 1stFlrSF        비대칭도(Skewness): 00.66     첨도(Kurtosis): 000.02
# 2ndFlrSF        비대칭도(Skewness): 00.77     첨도(Kurtosis): -00.80
# ...

# %% [markdown]
# #### 상관 관계(Correlation) Heat Map

# %%
# 변수간 상관 관계 확인
# 또한 'SalePrice'와의 상관 관계 확인
# 'GrLivArea', 'TotalBsmtSF'및 'OverallQual'가 큰 관계를 보임
# 나머지 변수와의 상관 관계를 자세히 알아보기 위해 Zoomed Heat Map 확인

corr_data = df_train[['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
                      'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
                      'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
                      'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
                      'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
                      'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
                      'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
                      'MiscVal', 'MoSold', 'YrSold', 'SalePrice']]

colormap = plt.cm.PuBu

f, ax = plt.subplots(figsize=(10, 10))
plt.title('Correlation of Numeric Features with Sale Price', y=1, size=18)
sns.heatmap(corr_data.corr(), square=True, linewidths=0.1,
            cmap=colormap, linecolor="white", vmax=0.8)
# Out:
# <AxesSubplot:title={'center':'Correlation of Numeric Features with Sale Price'}>

# %% [markdown]
# #### 확대 HeatMap

# %%
# GarageCars와 GarageArea, TotalBsmtSF와 1stFlrSF 는 서로 밀접하게 연관되어 있음
# Target feature와 가장 밀접한 연관이 있는 feature는 'OverallQual', 'GrLivArea'및 'TotalBsmtSF'로 보임
# GarageCars와 GarageArea, TotalBsmtSF와 1stFlrSF, TotRmsAbvGrd와 GrLivArea는 모두 매우 유사한 정보를 포함하고 있으며 다중공선성이 나타남
# SalePrice와 더 연관되어있는 변수인 GarageCars와 TotalBsmtSF, GrLivArea를 남기고 나머지는 이후에 버리도록 함

k= 11
cols = corr_data.corr().nlargest(k,'SalePrice')['SalePrice'].index
print(cols)
cm = np.corrcoef(df_train[cols].values.T)
f , ax = plt.subplots(figsize = (10,8))
sns.heatmap(cm, vmax=.8, linewidths=0.1,square=True,annot=True,cmap=colormap,
            linecolor="white",xticklabels = cols.values ,annot_kws = {'size':14} ,yticklabels = cols.values)
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'YearBuilt', 'FullBath', 'TotRmsAbvGrd',
#        'YearRemodAdd'],
#       dtype='object')
# <AxesSubplot:>

# %% [markdown]
# #### Pair Plot

# %%
# 위의 Zoomed Heat Map에서 다중공선성을 보이는 변수 중 SalePrice와 연관이 덜 한 변수를 제외하고 PairPlot을 그림
# 'TotalBsmtSF'와 'GrLiveArea'는 데이터 설명에서 알 수 있듯이 지하실의 면적과 생활공간 면적을 의미함
# 'TotalBsmtSF'와 'GrLiveArea'의 plot을 보면 점들이 직선처럼 그려지고 대부분의 점은 해당 선 아래에 유지됨
#  -> 이것은 일반적으로 지하실 면적이 지상 생활 면적과 같을 수 있지만, 더 크진 않기 때문에 보여지는 특징
# 'SalePrice'와 'YearBuilt'의 plot을 보면 우상향 곡선을 보임
#  -> 이것은 전년도 대비 주택 가격 상승의 가속을 의미한다고 할 수 있음

sns.set()
columns = ['SalePrice', 'OverallQual', 'TotalBsmtSF', 'GrLivArea',
           'GarageCars', 'FullBath', 'YearBuilt', 'YearRemodAdd']
sns.pairplot(df_train[columns], height=2, kind='scatter', diag_kind='kde')
plt.show()

# %% [markdown]
# #### Scatter Plot

# %%
# Target Feature "SalePrice"와 가장 밀접한 연관이 있다고 판단됐던 변수들의 Scatter Plot을 그림
# OverallQual, GarageCars, Fullbath와 같은 변수들은 실제로는 범주형 데이터의 특징을 보인다고 할 수 있음 (등급, 갯수 등을 의미하기 때문)

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(
    nrows=3, ncols=2, figsize=(16,13))

OverallQual_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['OverallQual']], axis=1)
sns.regplot(x='OverallQual', y='SalePrice',
            data=OverallQual_scatter_plot, scatter=True, fit_reg=True, ax=ax1)

TotalBsmtSF_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['TotalBsmtSF']], axis=1)
sns.regplot(x='TotalBsmtSF', y='SalePrice',
            data=TotalBsmtSF_scatter_plot, scatter=True, fit_reg=True, ax=ax2)

GrLivArea_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['GrLivArea']], axis=1)
sns.regplot(x='GrLivArea', y='SalePrice',
            data=GrLivArea_scatter_plot, scatter=True, fit_reg=True, ax=ax3)

GarageCars_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['GarageCars']], axis=1)
sns.regplot(x='GarageCars', y='SalePrice',
            data=GarageCars_scatter_plot, scatter=True, fit_reg=True, ax=ax4)

FullBath_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['FullBath']], axis=1)
sns.regplot(x='FullBath', y='SalePrice', data=FullBath_scatter_plot,
            scatter=True, fit_reg=True, ax=ax5)

YearBuilt_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['YearBuilt']], axis=1)
sns.regplot(x='YearBuilt', y='SalePrice',
            data=YearBuilt_scatter_plot, scatter=True, fit_reg=True, ax=ax6)

YearRemodAdd_scatter_plot = pd.concat(
    [df_train['SalePrice'], df_train['YearRemodAdd']], axis=1)
YearRemodAdd_scatter_plot.plot.scatter('YearRemodAdd', 'SalePrice')
# Out:
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %% [markdown]
# ### - Categorical Data 탐색

# %%
# 범주형 변수들과 각 범주들을 확인

for catg in list(catg_feats):
    print(df_train[catg].value_counts())
    print('-'*30)
# Out:
# RL         1055
# RM          197
# FV           65
# RH           14
# C (all)       7
# Name: MSZoning, dtype: int64
# ------------------------------
# Pave    1335
# Grvl       3
# Name: Street, dtype: int64
# ------------------------------
# Grvl    42
# Pave    37
# Name: Alley, dtype: int64
# ------------------------------
# Reg    859
# IR1    440
# IR2     32
# IR3      7
# Name: LotShape, dtype: int64
# ------------------------------
# Lvl    1211
# Bnk      52
# HLS      48
# Low      27
# Name: LandContour, dtype: int64
# ------------------------------
# AllPub    1338
# Name: Utilities, dtype: int64
# ------------------------------
# Inside     972
# Corner     235
# CulDSac     81
# FR2         46
# FR3          4
# Name: LotConfig, dtype: int64
# ------------------------------
# Gtl    1275
# Mod      56
# Sev       7
# Name: LandSlope, dtype: int64
# ------------------------------
# NAmes      205
# CollgCr    149
# OldTown     93
# Edwards     92
# Somerst     85
# ...

# %% [markdown]
# #### Box Plot

# %%
# BoxPlot을 그려 Categorical Feature와 SalePrice의 관계 확인
# 일부 범주는 다른 범주보다 SalePrice와 관련하여 더 다양하게 보임
# Neighborhood 변수는 주택 가격 편차가 매우 크므로 영향이 큼
# SaleType 또한 마찬가지
# 또한 수영장이 있으면 가격이 크게 증가
# 정리하면 SalePrice에 영향을 많이 끼치는 변수로는
# 'MSZoning', 'Neighborhood', 'Condition2', 'MasVnrType', 'ExterQual', 'BsmtQual', 'CentralAir', 'Electrical', 'KitchenQual', 'SaleType' 등이 있음

li_catg_feats = list(catg_feats)
rows = 15
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols*4, rows*3))

for r in range(0, rows):
    for c in range(0, cols):
        i = r*cols + c
        if i < len(li_catg_feats):
            sns.boxplot(
                x=li_catg_feats[i], y=df_train["SalePrice"], data=df_train, ax=axs[r][c])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 변수 분리

# %%
# 편의를 위해 SalePrice와 관련이 큰 변수와 아닌 변수를 분리
# "Id"는 submission 때문에 따로 빼놓음

# 숫자형 변수
num_strong_corr = ['SalePrice', 'OverallQual', 'TotalBsmtSF', 'GrLivArea', 'GarageCars',
                   'FullBath', 'YearBuilt', 'YearRemodAdd']

num_weak_corr = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallCond', 'MasVnrArea', 'BsmtFinSF1',
                 'BsmtFinSF2', 'BsmtUnfSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath',
                 'BsmtHalfBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
                 'Fireplaces', 'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
                 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# 범주형 변수
catg_strong_corr = ['MSZoning', 'Neighborhood', 'Condition2', 'MasVnrType', 'ExterQual',
                    'BsmtQual', 'CentralAir', 'Electrical', 'KitchenQual', 'SaleType']

catg_weak_corr = ['Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
                  'LandSlope', 'Condition1',  'BldgType', 'HouseStyle', 'RoofStyle',
                  'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterCond', 'Foundation',
                  'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
                  'HeatingQC', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish',
                  'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
                  'SaleCondition']

# %% [markdown]
# ## Feature Engineering
# ### Log 변환
# - SalePrice -> SalePrice_Log

# %%
# Target Feature인 SalePrice의 비대칭도와 첨도 확인
# 그래프와 수치를 확인하면 정상적으로 분포되지 않는것을 확인 가능
# 예측의 정확도를 높히기 위해 로그 변환

f, ax = plt.subplots(1, 1, figsize=(10, 6))
g = sns.histplot(df_train["SalePrice"], color="b", label="Skewness: {:2f}".format(
    df_train["SalePrice"].skew()), kde=True, stat="density", ax=ax)
g = g.legend(loc="best")

print("비대칭도 : %f" % df_train["SalePrice"].skew())
print("첨도 : %f" % df_train["SalePrice"].kurt())
# Out:
# 비대칭도 : 1.287364
# 첨도 : 2.555029

# %%
# 비대칭도, 첨도를 없애주기 위해 로그를 취해줌
# Log변환을 수행한 새로운 feature "SalePrice_Log"를 만들고 전 Feature인 "Saleprice"를 버림
# 로그를 취해준 그래프와 수치가 바뀐 모습을 볼 수 있음 (정규근사화)

df_train["SalePrice_Log"] = df_train["SalePrice"].map(
    lambda i: np.log(i) if i > 0 else 0)

f, ax = plt.subplots(1, 1, figsize=(10, 6))
g = sns.histplot(df_train["SalePrice_Log"], color="b", label="Skewness: {:2f}".format(
    df_train["SalePrice_Log"].skew()), kde=True, stat="density", ax=ax)
g = g.legend(loc="best")

print("비대칭도 : %f" % df_train['SalePrice_Log'].skew())
print("첨도 : %f" % df_train['SalePrice_Log'].kurt())

df_train.drop('SalePrice', axis=1, inplace=True)
# Out:
# 비대칭도 : -0.032026
# 첨도 : 0.571897

# %% [markdown]
# ### 결측 데이터 처리

# %%
# '없다'의 의미를 갖는 변수들
# NaN을 없다는 의미의 None으로 대체

cols_fillna = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu',
               'GarageQual', 'GarageCond', 'GarageFinish', 'GarageType', 'Electrical',
               'KitchenQual', 'SaleType', 'Functional', 'Exterior2nd', 'Exterior1st',
               'BsmtExposure', 'BsmtCond', 'BsmtQual', 'BsmtFinType1', 'BsmtFinType2',
               'MSZoning', 'Utilities']

for col in cols_fillna:
    df_train[col].fillna('None', inplace=True)
    df_test[col].fillna('None', inplace=True)

# %%
# 결측치의 처리 정도를 확인

total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()
           ).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#               Total   Percent
# LotFrontage     229  0.171151
# GarageYrBlt      65  0.048580
# MasVnrArea        7  0.005232
# Id                0  0.000000
# KitchenAbvGr      0  0.000000

# %%
# 나머지 결측치들은 평균값으로 대체
# 바로 결측값을 채워넣기 - inplace

df_train.fillna(df_train.mean(), inplace=True)
df_test.fillna(df_test.mean(), inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4032\3840478734.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_train.fillna(df_train.mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_4032\3840478734.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_test.fillna(df_test.mean(), inplace=True)

# %%
# 다시 결측치의 처리 정도를 확인

total = df_train.isnull().sum()
percent = (df_train.isnull().sum()/df_train.isnull().count()
           )
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#              Total  Percent
# Id               0      0.0
# MSSubClass       0      0.0
# MSZoning         0      0.0
# LotFrontage      0      0.0
# LotArea          0      0.0

# %%
df_train.isnull().sum().sum(), df_test.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# ### 유의하지 않은 변수 삭제

# %%
# SalePrice와의 상관관계가 약한 모든 변수 삭제

# id 행 따로 저장
id_test = df_test['Id']

to_drop_num = num_weak_corr
to_drop_catg = catg_weak_corr

cols_to_drop = ['Id'] + to_drop_num + to_drop_catg

for df in [df_train, df_test]:
    df.drop(cols_to_drop, inplace=True, axis=1)

# 삭제가 됬는지 확인
df_train.head()
# Out:
#   MSZoning Neighborhood Condition2  OverallQual  YearBuilt  YearRemodAdd  \
# 0       RL      CollgCr       Norm            7       2003          2003
# 1       RL      Veenker       Norm            6       1976          1976
# 2       RL      CollgCr       Norm            7       2001          2002
# 3       RL      Crawfor       Norm            7       1915          1970
# 4       RL      NoRidge       Norm            8       2000          2000
#
#   MasVnrType ExterQual BsmtQual  TotalBsmtSF CentralAir Electrical  GrLivArea  \
# 0    BrkFace        Gd       Gd          856          Y      SBrkr       1710
# 1       None        TA       Gd         1262          Y      SBrkr       1262
# 2    BrkFace        Gd       Gd          920          Y      SBrkr       1786
# 3       None        TA       TA          756          Y      SBrkr       1717
# 4    BrkFace        Gd       Gd         1145          Y      SBrkr       2198
#
# ...

# %% [markdown]
# ### 범주형 데이터(Categorical Data) 형변환

# %%
# 각 범주들을 개별로 확인
catg_list = catg_strong_corr.copy()
catg_list.remove('Neighborhood')

for catg in catg_list:
    sns.violinplot(x=catg, y=df_train["SalePrice_Log"], data=df_train)
    plt.show()

# %%
# 범주가 가장 많은 Neighborhood 변수 확인
fig, ax = plt.subplots()
fig.set_size_inches(16, 5)
sns.violinplot(x='Neighborhood',
               y=df_train["SalePrice_Log"], data=df_train, ax=ax)
plt.xticks(rotation=45)
plt.show()

# %%
# 각 범주들에 해당되는 SalePrice_Log 평균 확인
for catg in catg_list:
    g = df_train.groupby(catg)["SalePrice_Log"].mean().sort_values(ascending=True)
    print(g)
# Out:
# MSZoning
# C (all)    10.960733
# RM         11.677434
# RH         11.700602
# RL         12.069474
# FV         12.246616
# Name: SalePrice_Log, dtype: float64
# Condition2
# RRNn      11.435329
# Artery    11.570036
# Feedr     11.734675
# RRAn      11.827043
# Norm      12.012766
# PosN      12.860999
# Name: SalePrice_Log, dtype: float64
# MasVnrType
# BrkCmn     11.757397
# None       11.884715
# BrkFace    12.150038
# Stone      12.391766
# Name: SalePrice_Log, dtype: float64
# ExterQual
# Fa    11.274881
# TA    11.828332
# Gd    12.295102
# Ex    12.727937
# Name: SalePrice_Log, dtype: float64
# BsmtQual
# None    11.572903
# Fa      11.585725
# TA      11.791989
# Gd      12.170320
# Ex      12.595497
# Name: SalePrice_Log, dtype: float64
# CentralAir
# N    11.471479
# Y    12.042717
# Name: SalePrice_Log, dtype: float64
# Electrical
# Mix      11.112448
# FuseP    11.256345
# FuseF    11.565700
# FuseA    11.641350
# None     12.028739
# SBrkr    12.047595
# ...

# %%
# 수치형 변환을 위해 Violinplot과 SalePrice_Log 평균을 참고하여 각 변수들의 범주들을 그룹화

# 'MSZoning'
msz_catg2 = ['RM', 'RH']
msz_catg3 = ['RL', 'FV']


# Neighborhood
nbhd_catg2 = ['Blmngtn', 'ClearCr', 'CollgCr', 'Crawfor',
              'Gilbert', 'NWAmes', 'Somerst', 'Timber', 'Veenker']
nbhd_catg3 = ['NoRidge', 'NridgHt', 'StoneBr']

# Condition2
cond2_catg2 = ['Norm', 'RRAe']
cond2_catg3 = ['PosA', 'PosN']

# SaleType
SlTy_catg1 = ['Oth']
SlTy_catg3 = ['CWD']
SlTy_catg4 = ['New', 'Con']

# %%
# 각 범주별로 수치형 변환을 실행
for df in [df_train, df_test]:

    df['MSZ_num'] = 1
    df.loc[(df['MSZoning'].isin(msz_catg2)), 'MSZ_num'] = 2
    df.loc[(df['MSZoning'].isin(msz_catg3)), 'MSZ_num'] = 3

    df['NbHd_num'] = 1
    df.loc[(df['Neighborhood'].isin(nbhd_catg2)), 'NbHd_num'] = 2
    df.loc[(df['Neighborhood'].isin(nbhd_catg3)), 'NbHd_num'] = 3

    df['Cond2_num'] = 1
    df.loc[(df['Condition2'].isin(cond2_catg2)), 'Cond2_num'] = 2
    df.loc[(df['Condition2'].isin(cond2_catg3)), 'Cond2_num'] = 3

    df['Mas_num'] = 1
    df.loc[(df['MasVnrType'] == 'Stone'), 'Mas_num'] = 2

    df['ExtQ_num'] = 1
    df.loc[(df['ExterQual'] == 'TA'), 'ExtQ_num'] = 2
    df.loc[(df['ExterQual'] == 'Gd'), 'ExtQ_num'] = 3
    df.loc[(df['ExterQual'] == 'Ex'), 'ExtQ_num'] = 4

    df['BsQ_num'] = 1
    df.loc[(df['BsmtQual'] == 'Gd'), 'BsQ_num'] = 2
    df.loc[(df['BsmtQual'] == 'Ex'), 'BsQ_num'] = 3

    df['CA_num'] = 0
    df.loc[(df['CentralAir'] == 'Y'), 'CA_num'] = 1

    df['Elc_num'] = 1
    df.loc[(df['Electrical'] == 'SBrkr'), 'Elc_num'] = 2

    df['KiQ_num'] = 1
    df.loc[(df['KitchenQual'] == 'TA'), 'KiQ_num'] = 2
    df.loc[(df['KitchenQual'] == 'Gd'), 'KiQ_num'] = 3
    df.loc[(df['KitchenQual'] == 'Ex'), 'KiQ_num'] = 4

    df['SlTy_num'] = 2
    df.loc[(df['SaleType'].isin(SlTy_catg1)), 'SlTy_num'] = 1
    df.loc[(df['SaleType'].isin(SlTy_catg3)), 'SlTy_num'] = 3
    df.loc[(df['SaleType'].isin(SlTy_catg4)), 'SlTy_num'] = 4

# %%
# 변환하여 새로 만들어진 numerical feature들 또한 Heat Map 확인
# NbHd_num, ExtQ_num, BsQ_num, KiQ_num를 제외하고는 SalePrice_Log와 큰 상관관계가있는 열은 거의 없음
new_col_HM = df_train[['SalePrice_Log', 'MSZ_num', 'NbHd_num', 'Cond2_num',
                       'Mas_num', 'ExtQ_num', 'BsQ_num', 'CA_num', 'Elc_num', 'KiQ_num', 'SlTy_num']]

colormap = plt.cm.PuBu
plt.figure(figsize=(10, 8))
plt.title("Correlation of New Features", y=1, size=15)
sns.heatmap(new_col_HM.corr(), linewidths=0.1, vmax=1.0,
            square=True, cmap=colormap, linecolor="white", annot=True, annot_kws={"size": 12})
# Out:
# <AxesSubplot:title={'center':'Correlation of New Features'}>

# %%
# 기존 범주형 변수와 새로 만들어진 수치형 변수 역시 유의하지 않은 것들은 삭제
df_train.drop(['MSZoning', 'Neighborhood', 'Condition2', 'MasVnrType', 'ExterQual', 'BsmtQual', 'CentralAir', 'Electrical',
              'KitchenQual', 'SaleType', 'Cond2_num', 'Mas_num', 'CA_num', 'Elc_num', 'SlTy_num'], axis=1, inplace=True)
df_test.drop(['MSZoning', 'Neighborhood', 'Condition2', 'MasVnrType', 'ExterQual', 'BsmtQual', 'CentralAir', 'Electrical',
             'KitchenQual', 'SaleType', 'Cond2_num', 'Mas_num', 'CA_num', 'Elc_num', 'SlTy_num'], axis=1, inplace=True)

# 완벽히 삭제되어 유의하다고 판단되는 수치형 변수만 남기기
df_train.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  GrLivArea  FullBath  \
# 0            7       2003          2003          856       1710         2
# 1            6       1976          1976         1262       1262         2
# 2            7       2001          2002          920       1786         2
# 3            7       1915          1970          756       1717         1
# 4            8       2000          2000         1145       2198         2
#
#    GarageCars  SalePrice_Log  MSZ_num  NbHd_num  ExtQ_num  BsQ_num  KiQ_num
# 0           2      12.247694        3         2         3        2        3
# 1           2      12.109011        3         2         2        2        2
# 2           2      12.317167        3         2         3        2        3
# 3           3      11.849398        3         2         2        1        3
# 4           3      12.429216        3         3         3        2        3

# %%
df_test.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  GrLivArea  FullBath  \
# 0            5       1961          1961        882.0        896         1
# 1            6       1958          1958       1329.0       1329         1
# 2            5       1997          1998        928.0       1629         2
# 3            6       1998          1998        926.0       1604         2
# 4            8       1992          1992       1280.0       1280         2
#
#    GarageCars  MSZ_num  NbHd_num  ExtQ_num  BsQ_num  KiQ_num
# 0         1.0        2         1         2        1        2
# 1         1.0        3         1         2        1        3
# 2         2.0        3         2         2        2        2
# 3         2.0        3         2         2        1        3
# 4         2.0        3         3         3        2        3

# %% [markdown]
# ## 모델링 / Submission 만들기

# %%
# Test하기 전 Validation(중간점검, 확인) 과정을 거치기
# train데이터의 20%를 validation으로 주고 80%을 train(학습용)으로 남겨주어 분리
from sklearn.model_selection import train_test_split
from sklearn import metrics

X_train = df_train.drop("SalePrice_Log", axis=1)
target_label = df_train["SalePrice_Log"]
X_test = df_test
X_tr, X_vld, y_tr, y_vld = train_test_split(
    X_train, target_label, test_size=0.2, random_state=2000)

# %%
# XGBoost 모델
import xgboost
regressor = xgboost.XGBRegressor(colsample_bytree=0.4603, learning_rate=0.06, min_child_weight=1.8,
                                 max_depth=3, subsample=0.52, n_estimators=2000,
                                 random_state=7)
regressor.fit(X_tr, y_tr)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.4603,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=3, max_leaves=0, min_child_weight=1.8,
#              missing=nan, monotone_constraints='()', n_estimators=2000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=7,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
# 예측 된 y 값 (y_hat)에 대한 Scatter Plot 도출
y_hat = regressor.predict(X_tr)

plt.scatter(y_tr, y_hat, alpha=0.2)
plt.xlabel('Targets (y_tr)', size=18)
plt.ylabel('Predictions (y_hat)', size=18)
plt.show()

# %%
regressor.score(X_tr,y_tr)
# Out:
# 0.9777942354360256

# %%
# validation으로 예측
y_hat_test = regressor.predict(X_vld)

plt.scatter(y_vld, y_hat_test, alpha=0.2)
plt.xlabel('Targets (y_vld)', size=18)
plt.ylabel('Predictions (y_hat_test)', size=18)
plt.show()

# %%
regressor.score(X_vld,y_vld)
# Out:
# 0.8423940303909464

# %%
# k-fold validation 수행
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=regressor, X=X_tr, y=y_tr, cv=10)

# %%
# 정확도 확인
print(accuracies.mean())
print(accuracies.std())
# Out:
# 0.8479323603434036
# 0.032273951502301806

# %%
# use_logvals는 Log를 취해준 Target feature을 exp해주기 위해 사용되는 스위치 역할
# 제대로 된 예측을 위해 학습 후 Log변환 풀기
# 이 셀의 코드를 통해 submission까지 완료
pred_xgb = regressor.predict(X_test)

# 데이터 프레임(Submission)
sub_xgb = pd.DataFrame()
sub_xgb['Id'] = id_test
sub_xgb['SalePrice'] = pred_xgb

sub_xgb['SalePrice'] = np.exp(sub_xgb['SalePrice'])

sub_xgb.to_csv('xgb.csv', index=False)

# %%
#import sklearn.externals
import joblib
joblib.dump(regressor, "HouseModel.pkl")
# Out:
# ['HouseModel.pkl']
